# %% [markdown]
# # Module 5.2: Loading and Inspecting Data with pandas
#
# **Data Analysis Programme · Week 6 · Module 5, Python for Data Analysis**
#
# This notebook is the hands-on lab for Module 5.2. It assumes you have completed
# **Module 5.1, Python Fundamentals Consolidated**.
#
# **By the end of this notebook you can:**
# - Import pandas.
# - Load a CSV file into a DataFrame.
# - Explain what rows, columns and a DataFrame are.
# - Inspect dataset dimensions.
# - Inspect data types.
# - Identify missing values.
# - Select columns.
# - Select rows using conditions.
# - Answer simple analytical questions from a dataset.
#
# Run each cell in order, top to bottom.

# %% [markdown]
# ## Setup: create today's dataset
#
# This cell writes `branch_sales.csv` to your Colab environment so the rest of the
# notebook can load it like a real file. You will not usually write your own CSV like
# this outside of a lab, it exists so this notebook is self-contained. Run it once.

# %%
with open("branch_sales.csv", "w") as f:
    f.write("""TransactionID,Branch,Region,Customer,Product,Sales,Profit,Price,Date
1,Lagos,South West,Sunrise Stores,Rice 50kg,145000,21750,29000,2026-01-05
2,Abuja,North Central,Greenfield Traders,Cooking Oil 25L,98000,14700,,2026-01-05
3,Kano,North West,Kings Mart,Detergent Carton,52000,7800,13000,2026-01-06
4,Lagos,South West,Delta Provisions,Beverages Crate,132000,19800,11000,2026-01-06
5,Ibadan,South West,Horizon Retailers,Flour 50kg,87000,13050,,2026-01-07
6,Abuja,North Central,Prime Foods Ltd,Rice 50kg,156000,23400,31000,2026-01-07
7,Kano,North West,Unity Traders,Cooking Oil 25L,64000,9600,16000,2026-01-08
8,Lagos,South West,Coastal Mart,Detergent Carton,45000,6750,,2026-01-08
9,Ibadan,South West,Sunrise Stores,Beverages Crate,119000,17850,9800,2026-01-09
10,Abuja,North Central,Greenfield Traders,Flour 50kg,102000,15300,25500,2026-01-09
11,Kano,North West,Kings Mart,Rice 50kg,178000,26700,29500,2026-01-10
12,Lagos,South West,Delta Provisions,Cooking Oil 25L,93000,13950,15800,2026-01-10
13,Ibadan,South West,Horizon Retailers,Detergent Carton,38000,5700,12500,2026-01-11
14,Abuja,North Central,Prime Foods Ltd,Beverages Crate,141000,21150,10200,2026-01-11
15,Kano,North West,Unity Traders,Flour 50kg,76000,11400,24000,2026-01-12
16,Lagos,South West,Coastal Mart,Rice 50kg,205000,30750,30500,2026-01-12
17,Ibadan,South West,Sunrise Stores,Cooking Oil 25L,58000,8700,,2026-01-13
18,Abuja,North Central,Greenfield Traders,Detergent Carton,49000,7350,13200,2026-01-13
19,Kano,North West,Kings Mart,Beverages Crate,167000,25050,10500,2026-01-14
20,Lagos,South West,Delta Provisions,Flour 50kg,110000,16500,26000,2026-01-14
""")

print("branch_sales.csv is ready.")

# %% [markdown]
# ## 1. What is pandas?
#
# pandas is Python's library for working with tables of data: rows and columns, just
# like a spreadsheet. It turns the lists of dictionaries you built in Module 5.1 into
# one structured table you can sort, filter, summarise and clean in a few lines.
#
# > "A pandas DataFrame is like an Excel worksheet that Python can manipulate
# > programmatically."
#
# ## 2. Import pandas

# %%
import pandas as pd

# %% [markdown]
# - `import` — brings a library into this notebook, exactly as in Module 5.1.
# - `pandas` — the library itself, already installed in Google Colab.
# - `as pd` — gives it a short nickname, so every later line reads `pd.something`
#   instead of `pandas.something`.

# %% [markdown]
# ## 3. Loading a CSV
#
# `pd.read_csv(...)` opens the named file, reads every row and column into memory,
# and stores the whole table in the variable you assign it to.

# %%
df = pd.read_csv("branch_sales.csv")
df

# %% [markdown]
# **Excel parallel:** this is the Python equivalent of double-clicking a CSV to open
# it in Excel, except the result is a variable you can compute on, not a window you
# look at.

# %% [markdown]
# ## 4. Understanding the DataFrame
#
# - **Columns** — the named fields across the top (`Branch`, `Product`, `Sales`, ...).
# - **Index** — the row labels down the left (`0, 1, 2, ...` by default).
# - **Row** — one full record, e.g. one transaction.
# - **Value** — one cell, e.g. the Sales figure for one transaction.
#
# Look at the table `df` printed above: rows and an index down the left, named
# columns across the top, one value in every cell, exactly like a worksheet.

# %% [markdown]
# ## 5. First inspection
#
# Run each of these on `df` and compare what each one tells you.

# %%
df.head()

# %%
df.tail()

# %%
df.shape

# %%
df.info()

# %%
df.describe()

# %% [markdown]
# | Command | When an analyst uses it |
# |---|---|
# | `df.head()` | See the first 5 rows, to sanity-check the load worked |
# | `df.tail()` | See the last 5 rows, useful for checking where a file ends |
# | `df.shape` | Confirm the row and column count matches what you expect |
# | `df.info()` | See every column, its data type and how many values are non-missing |
# | `df.describe()` | Get summary statistics for the numeric columns, at a glance |
#
# Make `head()`, `shape` and `info()` the first three commands you run on any new
# file, before you write a single line of analysis.

# %% [markdown]
# ## 6. Data types

# %%
df.dtypes

# %% [markdown]
# - `int64` — whole numbers, e.g. `TransactionID`, `Sales`.
# - `float64` — numbers with decimals, or a numeric column that contains missing
#   values, e.g. `Price`.
# - `object` — text, e.g. `Branch`, `Product`, `Date`.
# - `bool` — a `True`/`False` check, as in Module 5.1's `target_met`.
#
# **Why it matters:** pandas cannot average a column it thinks is text, and a column
# with even one missing value often becomes `float64` instead of `int64`. Both are
# diagnostic clues, not accidents.

# %% [markdown]
# ## 7. Missing values

# %%
df.isna().sum()

# %% [markdown]
# - `isna()` marks every missing cell `True`, everything else `False`.
# - `sum()` adds the `True`s down each column, one number per column.
#
# **Why analysts check this first:** a missing price left unnoticed can silently
# break a calculation later. This is exactly the check that would have caught
# Module 5.1's currency-formatting error before it became one. Run it before any
# analysis, not after something looks wrong.

# %% [markdown]
# ## 8. Selecting columns
#
# One column name in single brackets returns a **Series**.

# %%
df["Sales"]

# %% [markdown]
# A list of column names in double brackets returns a **DataFrame**.

# %%
df[["Sales", "Profit"]]

# %% [markdown]
# **The difference:** single brackets with one name return a Series, a single
# labelled column, like clicking one column header in Excel. Double brackets with a
# list of names return a DataFrame, a smaller table, like ctrl-selecting several
# columns and copying them to a new sheet.

# %% [markdown]
# ## 9. Filtering rows

# %%
df[df["Sales"] > 100000]

# %% [markdown]
# - `df["Sales"] > 100000` checks every row and produces `True` or `False`.
# - Wrapping it in `df[...]` keeps only the rows marked `True`.
#
# **Excel parallel:** the same result as clicking Excel's filter arrow and keeping
# only Sales greater than 100,000, except this filter is one line you can rerun on
# next month's file instantly.
#
# Combine conditions with `&` (and) or `|` (or), and wrap each condition in its own
# parentheses.

# %% [markdown]
# ## 10. Asking analytical questions
#
# Every one of these is a business question first, and a line of pandas second.
#
# **Which customers have sales above ₦150,000?**

# %%
df[df["Sales"] > 150000]["Customer"]

# %% [markdown]
# **Which transactions occurred in the North West region?**

# %%
df[df["Region"] == "North West"]

# %% [markdown]
# **Which products have missing prices?**

# %%
df[df["Price"].isna()]["Product"]

# %% [markdown]
# ## 11. Excel → pandas translation
#
# | Excel | pandas |
# |---|---|
# | Open CSV | `pd.read_csv()` |
# | Filter | Boolean filtering, e.g. `df[df["Sales"] > 100000]` |
# | View first rows | `.head()` |
# | Count rows/columns | `.shape` |
# | Inspect columns | `.info()` |
# | Check missing values | `.isna()` |
#
# Nothing here is a new idea, only a new way of writing something you already know
# how to do in Excel.

# %% [markdown]
# ## 12. Guided exercise: branch_sales.csv
#
# Twenty transactions, four branches, one missing-price column to find. Answer each
# question with code in the cell below it. Try every task yourself before checking
# the instructor answer key on publica.academy.
#
# **Time-box:** 20 minutes.

# %% [markdown]
# **Q1. Load `branch_sales.csv` into a DataFrame named `df`.** (already done above, re-run here for practice)

# %%
# your code here

# %% [markdown]
# **Q2. How many rows and columns does `df` have, and what are the column data types?**

# %%
# your code here

# %% [markdown]
# **Q3. Which column has missing values, and how many are missing?**

# %%
# your code here

# %% [markdown]
# **Q4. Create a new DataFrame with only the `Branch`, `Product` and `Price` columns.**

# %%
# your code here

# %% [markdown]
# **Q5. Show only the transactions where `Region` is "South West" and `Sales` is above ₦100,000.**

# %%
# your code here

# %% [markdown]
# ---
#
# Check your answers against the instructor answer key in
# `Module_5.2_Loading_and_Inspecting_Data.md` before moving on to Module 5.3.
